# %%
import pandas as pd
import os
import sys
sys.path.append(os.path.abspath(".."))
from src.preprocessing.nltkProcessing import nltk_stemming_function
df=pd.read_csv("../data/processed/imbd.csv")
df["review"]=df["review"].apply(nltk_stemming_function)
df.to_csv("../data/processed/imbd.csv")

# %%
# Movie Review Intelligence Platform
# │
# ├── Sentiment Analysis (ML)
# ├── Emotion Detection (ML)
# ├── Review Insights Dashboard
# ├── Smart Review Reply Suggestion (Rule-based)
# ├── Review Statistics
# └── Explainable AI (Top Positive/Negative Words)
