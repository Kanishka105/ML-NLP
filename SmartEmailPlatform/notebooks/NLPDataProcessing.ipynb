# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath(".."))
from src.preprocessing.nltkProcessing import nltk_stemming_function, nltk_lemmatization_function
df1=pd.read_csv("../data/processed/spamEmail.csv")
df1["Tokenized_Message"] = df1["Message"].apply(nltk_processing_function)
df1 = df1[df1["Tokenized_Message"].str.strip() != ""].reset_index(drop=True)
df1.to_csv("../data/processed/spamEmail.csv",index=False)

df2=pd.read_csv("../data/processed/email_classification_dataset.csv")
df2["LemCombineText"]=df2["CombineText"]
df2["SumText"]=df2["CombineText"]
df2["Tokenized_body"]=df2["body"].apply(nltk_stemming_function)
df2["Tokenized_subject"]=df2["subject"].apply(nltk_stemming_function)
df2["CombineText"]=df2["CombineText"].apply(nltk_stemming_function)
df2.to_csv("../data/processed/email_classification_dataset.csv")






# why must create a column for nltk processing?
# Why?
# Debugging
# If something goes wrong later, you can compare the original cleaned text with the processed tokens.
# EDA
# You may want to calculate word count, sentence length, or visualize the original cleaned text.
# Experiments
# Later you might compare:
# No stemming
# Porter stemming
# Lemmatization
# Keeping the original cleaned text makes these experiments much easier.

# Later (Good Experiment)
# After completing the project, you can compare:
# Pipeline	Accuracy	Precision	Recall	F1
# Porter Stemmer	?	?	?	?
# WordNet Lemmatizer	?	?	?	?
# If lemmatization improves the results, mention that in your report.
# This comparison itself is a valuable addition to your project.
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\91798\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\91798\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\91798\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# 0    anniversary special buy one get one free as ou...
# 1    your amazon was used on new device your 5000 r...
# 2    re your google inquiry hi following up about y...
# Name: CombineText, dtype: str
# 0    anniversary special buy one get one free as ou...
# 1    your amazon was used on new device your 5000 r...
# 2    re your google inquiry hi following up about y...
# Name: LemCombineText, dtype: str
# 0    anniversari special buy one get one free loyal...
# ...
