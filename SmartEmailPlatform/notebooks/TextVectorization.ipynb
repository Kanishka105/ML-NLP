# %%
import os
import sys
import pandas as pd
sys.path.append(os.path.abspath(".."))
from src.models.model import model_evaluation
from src.models.EmailCategoryModel import email_classification_category_model
df=pd.read_csv("../data/processed/spamEmail.csv")
model_evaluation("Tokenized_Message","Category",df)
df2 = pd.read_csv("../data/processed/email_classification_dataset.csv")
email_classification_category_model(df2,'Tokenized_body', 'Tokenized_subject',"category")
# Out:
# ['Unnamed: 0.1', 'Unnamed: 0', 'id', 'subject', 'body', 'text', 'category', 'category_id', 'Tokenized_body', 'Tokenized_subject']
# 0        loyal custom get exclus 60 75 examplecom6058 o...
# 1        5000 refund process claim bitlyfakepr complet ...
# 2        hi follow googl applic rate drop 09 appli phis...
# 3        crosscultur ceremoni design join virtualritual...
# 4         trend cook 258 comment view supportsiteticket456
#                                ...
# 13472    alex anyon free weekend lisa count repli socia...
# 13473             access code 907472 transact author valid
# 13474     trend cook 258 comment view supportsiteticket456
# 13475    packag couldnt deliv track ab123 updat phishin...
# 13476    final hour biggest sale 30 examplecom7245 end ...
# Name: Tokenized_body, Length: 13477, dtype: str
# [{'Accuracy': 0.9885014836795252,
#   'Precision': 0.9885424093571494,
#   'Recall': 0.9885014836795252,
#   'F1 Score': 0.9885087788788081,
# ...

# %%
# # 
# 1. Spam Detection                     ✅
# 2. Email Category Classification      ✅
# 3. Smart Email Search                 ← TF-IDF + Cosine Similarity
# 4. Similar Email Finder
# 5. Keyword Extraction                 ⭐ Use POS Tagging
# 6. Email Summarization
# # 7. Reply Suggestiona

# %%
# 1. Cleaning
#         │
# 2. NLP
#         │
# 3. CountVectorizer
#         │
# 4. TF-IDF
#         │
# 5. Compare Models
#         │
# 6. Try Word Bigrams
#         │
# 7. Compare Again
#         │
# 8. Add Domain
#         │
# 9. Compare Again
#         │
# 10. Add Local Part
#         │
# 11. Compare Again
#         │
# 12. Add Country
#         │
# 13. Compare Again
#         │
# 14. Final Model



# Classification Algorithms
# │
# ├── Probabilistic
# │      └── Naive Bayes
# │
# ├── Linear Models
# │      ├── Logistic Regression
# │      └── Linear SVM
# │
# ├── Tree-Based
# │      ├── Decision Tree
# │      ├── Random Forest
# │      └── XGBoost
# │
# ├── Distance-Based
# │      └── K-Nearest Neighbors (KNN)
# │
# └── Neural Networks
#        └── Multi-Layer Perceptron (MLP)



# | Algorithm           | Use for Spam? | Reason                                                                        |
# | ------------------- | :-----------: | ----------------------------------------------------------------------------- |
# | Naive Bayes         |     ⭐⭐⭐⭐⭐     | Designed for text frequencies; excellent baseline.                            |
# | Logistic Regression |     ⭐⭐⭐⭐⭐     | Strong linear classifier for TF-IDF features.                                 |
# | Linear SVM          |     ⭐⭐⭐⭐⭐     | Often among the best classical NLP models.                                    |
# | Decision Tree       |       ⭐⭐      | Easy to understand but tends to overfit sparse text.                          |
# | Random Forest       |      ⭐⭐⭐      | Good comparison model, usually not the top performer on TF-IDF.               |
# | KNN                 |       ⭐       | High-dimensional text makes distance-based methods less effective.            |
# | XGBoost             |      ⭐⭐⭐      | Powerful, but more commonly used on structured/tabular data than sparse text. |
